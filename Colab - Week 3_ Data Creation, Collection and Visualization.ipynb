# %% [markdown]
# <div align="center">
#
# # YDS Week 3: Data Creation, Collection, and Visualization!

# %% [markdown]
# Dear Young Data Scientists,
#
# You've just completed the third session. It is an amazing achievement! ✌ (-‿-) ✌
#
# By this point, we have built together a skin tone histogram in week 1, crafted our cool word clouds in week 2, and gossiped about celebrities using data this week!
#
# Today, let's talk about data creation, collection, and visualization. Looks like we are going to cover three topics. Would this module be too overwhelming to read? No worries. It wouldn't because creation, collection, and visualization are steps you have already experienced/completed in previous activities (When you picked up color from magazine images, you were creating data).
#
# Please hold tight, we are getting started.
# <div align="right">
#
# Cheers,
#
# YDSL Team
#
# <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/HoldTight.gif" width ='200'>
# </figure>
# <div align="left">

# %% [markdown]
# # <div align="center">  New Information to Explore: **Data Creation**
#
# ***
# ## What is data creation?
#
# ### **Data creation** is the process of creating data to answer specific questions. ✍(◔◡◔)
#
#
#
# ***
# ### - Examples of data creation:
# 1. Do you know that more than 500,000 census takers across the nation go door to door to complete the 2020 Census? 👩🏻👨🏻🧔🏿‍🧓🏾👩🏽‍🍳
# Why demorgraphic data matters? The created data help allocate over $675 billion
# in federal funds every year and it helps states, local communities, and businesses make informed
#     decisions.
# <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/2019CensorData.png" width="450" >
#   <figcaption>Source: https://www.census.gov/popclock/</figcaption>
# </figure>
#
# 2. Companies conduct product surveys to learn what their users think about their products.
# <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/reasons-for-using-tiktok.jpeg" width="450" >
#   <figcaption>Source: https://www.digitalinformationworld.com/</figcaption>
# </figure>
#
# 3. Teachers give quizzes to students to collect data about how students understand the content. ᕙ(⇀‸↼‶)ᕗ
# <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/How_Hard_is_the_CFA_Exam.png" width="600" height="350">
#   <figcaption>Source: https://www.schweser.com//</figcaption>
# </figure>
# ***
# ### Ways to create data:
# 1. Conduct interviews. <font color=green>(༼ ºل͟º ༼ ºل͟º ༼ ºل͟º ༽ ºل͟º ༽ ºل͟º ༽ Not only journalists like Chris Wallace can do interviews. You can also conduct interviews.)</font>
#
# 2. Hand out surveys <font color=green>(ლ(╥﹏╥ლ) I never learn how to refuse a street survey.)</font>
# 3. Make observations
#
# <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/Observation.gif" width="300" >
# </figure>

# %% [markdown]
# ***
# ### Data scientists use computers to make data creation more efficient:
# 1. Artificial intelligence chatbot conducts conversations to help with customers' concerns.
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/Chatbot.gif", width ='600'>
#
# 2. Google forms allow us to send surveys to thousands of people at a time.
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/GoogleFormInstruction.gif", width ='600'>
#
#
# 3. Computer vision technologies applied in sports to observe points, fouls, penalties and positions for tactical analysis.
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/SoccerAnalysis.gif", width ='600'>
#
#
# ***

# %%
#@title Let us know your opinion about data creation:
import IPython
IPython.display.HTML('<iframe src="https://docs.google.com/forms/d/e/1FAIpQLSfxi0xVTbOXryOFqGnQlV5fCMJ7Gk3-xCntS7w9M3oQnYU0KQ/viewform?embedded=true" width="640" height="640" frameborder="0" marginheight="0" marginwidth="0">Loading…</iframe>')
# Out:
# <iframe src="https://docs.google.com/forms/d/e/1FAIpQLSfxi0xVTbOXryOFqGnQlV5fCMJ7Gk3-xCntS7w9M3oQnYU0KQ/viewform?embedded=true" width="640" height="640" frameborder="0" marginheight="0" marginwidth="0">Loading…</iframe>

# %% [markdown]
# ***
# ***
#
# # Data Collection
#
# ***
#
# ## What is data collection?
#
# ### **Data Collection** is the process of finding, gathering, organizing, and storing existing data. (<font color=green>Collecting data is like collecting shells. You need to find a beach that has shells. Then, you look for shells that you like the most!</font>)
# <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/ShellCollection.gif", width ='400'>
# </figure>
#
# ***
# <div align="left">
#
#
# ### Examples of data collection:
# | <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/AnimationDataCollection.gif" width='450' /> |  <font color="" size=4>*1. Downloading data from publically available sources. <br /> <br /> 2. Collecting chat history to generate a wordcloud. <br /> <br />  3. Finding and pulling data from print sources, collating it into databases.*</font> |
# |-|-|
#
#
# ***
#
# ### Where you can find amazing **data sources**:
# 1. [Google dataset search](https://datasetsearch.research.google.com/): A Google search engine for datasets.
# 2. [Awesome public datasets](https://github.com/awesomedata/awesome-public-datasets): All kinds of datasets from different areas.
#
#
# Last week, we asked ourselves where to find data to address the problems we proposed! Try our luck in these two oceans of data sources!! we may find our favarite shells there!!
#  <div align="center">
# <figure class="image">
#   <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/IHaveTheData.gif", width ='300'>
# </figure>
#
#
# ***
# ***
#
# <div align="left">
#
#
# # Data Creation vs. Data Collection
#
#  **Given a problem, which one do we need: data creation or data collection?**
#  The following diagram explains the best practice:
#  <div align="center">
# <figure class="image">
#   <img src="https://drive.google.com/uc?id=10GppmOoe1PRdquS3cFNMENBi-QHzpVl8">
#   <figcaption>  Diagram: <em>The procedure one should follow to decide when to create data and when to collect data.</em> </figcaption>
#   </figure>
#
# <div align="left">

# %% [markdown]
# # <div align="center">  New Information to Explore: **Data Visualization**
#
# ## Why is data visualization important?
#
# Good visualization makes the data more natural for the human mind to comprehend and therefore makes it easier to identify trends, patterns, and outliers within large data sets. Visualization is more important when we have multivariate data.
#
# ## Example:
# 1. Three features (time, location, number of "fever" related searches) are embedded in one visualization.
#  <div align="center">
# <figure class="image">
# <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/SearchForFever.gif", width ='700'>
# <figcaption>Understand the link between symptom-related searches and the spread of COVID-19; <br />
# Source: https://blog.google/technology/health/using-symptoms-search-trends-inform-covid-19-research/</figcaption>
# </figure>
#
#
#
#
# 2. In our skin tone activity, if we collect both the RGB value of the model's skin tone and the time when it was published, we have two variables(features) for each data point. With a good visualization, we will be able to see how skin tone representation change over time.
#
#  <div align="center">
# <figure class="image">
# <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/VogueSkinTone.png", width = '100%'>
# <figcaption>From 2000 to 2018, there have been 228 issues of Vogue, with a total of 262 female cover models. This figure shows the skin stone spectrum; <br />
# Source: https://pudding.cool/2019/04/vogue/</figcaption>
# </figure>
#
# 3. Data visualization can be a piece of art, hanging in your wall. Or you can give it to your loved ones as a gift. How romantic/warm that would be if the data being visualized is about your own life?
#  <div align="center">
# <figure class="image">
# <img src="https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/AirTrafficVIsualization.jpeg", width = '80%'>
# <figcaption> U.S. Air Traffic Visualisation <br />
# Source: https://pixels.com/featured/2-air-traffic-visualisation-aaron-koblinscience-photo-library.html?product=art-print</figcaption>
# </figure>

# %% [markdown]
# ## Common types of visualization:
#
# * Line Graph
#
# <div align="center">
# <figure class="image">
# <img src="
# https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/TikTokAdultUsers.png"= '80%'>
# <figcaption> Number of U.S. Adults Using TikTok.</figcaption>
# </figure>
# <div align="left">
#
#
# *   Pie Chart
#
# <div align="center">
# <figure class="image">
# <img src="
# https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/PieChart.png", width = '80%'>
# <figcaption> A pie chart plotted using data from your week 1 responses.</figcaption>
# </figure>
# <div align="left">
#
# * Scatter Plot
# <div align="center">
# <figure class="image">
# <img src="
# https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/DogScorevsPopularity.png", width = '120%'>
# <figcaption> A scatter plot usuallty has two main features. In this plot, we have two features: 1. a dog breed's greatness; 2. the popularity of this breed. </figcaption>
# </figure>
#
# * Word Cloud
#
# <div align="center">
# <figure class="image">
# <img src="
# https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/Word%20Art.png", width = '100%'>
# <figcaption> In last week's module, we sampled the topics you are interested in the most. We got 20+ reponses so far (2pm Pacific Time, 25 March, 2021). Here is the word cloud we plot based on the topics chosen by you!</figcaption>
# </figure>
# <div align="left">
#
#
# * Other common types of visualization used by data scientist include **heatmap**, **histogram**, **bar chart**, etc. If you want to explore more types of basic visualization, you don't want to miss [this link](https://datavizcatalogue.com/).
#
# ## Fancy Visualizations:
#
# Theses websites provide fancy and interesting visualizations. But most fancy visuazations can link back to these common types of visualization we just introduced. For example, The plot that shows the number of searchs for 'fever' across U.S. is originated from the 'headmap' family.
# 1. [FiveThirtyEight](https://fivethirtyeight.com/tag/data-visualization/)
# 2. [The Pudding](https://pudding.cool/)
# 3. [Information is Beautiful](https://informationisbeautiful.net/)
# 4. [U.S. Census](https://www.census.gov/dataviz/)
#
# Do you find your favorite visualization?  Share your favorite visualization with your teammates and explain why you like it.

# %% [markdown]
# # <div align="center">**THE END OF MODULE 3**
# A big kudos to you, guys! This week, we accomplished a lot! We learned more about our data science life cycle. Now, we understand what data creation, data collection, and data visualization are. We may already got some pretty good ideas about how to create or where to find data to solve our own problems. That is fantastic! That means we are one step closer to becoming a professional young data scientist!
#
# You have had a long journey reading this module. Now it is time to relax!! We will see you guys next week!
#
# <div align="center">
# <figure class="image">
# <img src="
# https://raw.githubusercontent.com/Yun-Han/YDSL_images/master/GoodBye.gif", width = '50%'>
# <figcaption> Farewell!</figcaption>
# </figure>
# <div align="left">
